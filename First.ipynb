# %% [markdown]
# Fonte dos dados:
#
# https://www2.fab.mil.br/cenipa/
#
# Acesso a informações
# Dados abertos
#
# Tabela de ocorrência
# http://landpage-h.cgu.gov.br/dadosabertos/index.php?url=http://sistema.cenipa.aer.mil.br/cenipa/media/opendata/ocorrencia.csv
#
# Remove extra columns to be equal to file in data.

# %%
import pandas as pd
import pandera as pa

# %%
# Find out your current working directory
import os
# print(os.getcwd())
base_dir = os.getcwd()
full_path = base_dir + "\data\ocorrencia.csv"

# Display all of the files found in your current working directory
# print(os.listdir(os.getcwd()))

# %%
# Add specific separator. It could ';' or ','.
df = pd.read_csv(full_path, sep=",", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head(10)

# If a string element is empty, then pandas shows 'NaN'. If it's a date, it shows 'NaT'.
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# ...

# %%
# schma to validate dataframe and column types
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)
    }
)

# %%
# It throws an error if a column is not the same type as schema
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.ocorrencia_dia.dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6109    8
# 6110    8
# 6111    8
# 6112    8
# 6113    8
# Name: ocorrencia_dia, Length: 6114, dtype: int64

# %%
# show the last 10 rows
df.tail(10)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6104              80238               80238          INCIDENTE GRAVE
# 6105              80239               80239                INCIDENTE
# 6106              80249               80249                INCIDENTE
# 6107              80243               80243                INCIDENTE
# 6108              80244               80244                INCIDENTE
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6104        VOTUPORANGA            SP                 SDVG     2021-08-11
# ...
